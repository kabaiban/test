# %% [markdown]
# <a href="https://colab.research.google.com/github/kabaiban/test/blob/master/%E9%85%8D%E8%89%B2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 載入所需套件

# %%
install.packages("ggplot2")
install.packages("SportsAnalytics")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# 讀取套件

# %%
library(SportsAnalytics)
library(ggplot2)

# %% [markdown]
# 利用order()排序球員總分

# %%
NBA1516<-fetch_NBAPlayerStatistics("15-16")

NBA1516order<-NBA1516[order(NBA1516$TotalPoints,decreasing = T),]
NBA1516order[1:20,]
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 178 NBA    James Harden     HOU  SG       82          3121
# 106 NBA    Stephen Curry    GSW  PG       79          2705
# 127 NBA    Kevin Durant     OKL  SF       72          2577
# 222 NBA    Lebron James     CLE  SF       76          2710
# 267 NBA    Damian Lillard   POR  PG       75          2673
# 453 NBA    Russel Westbrook OKL  PG       80          2749
# 154 NBA    Paul George      IND  SF       81          2828
# 116 NBA    Demar Derozan    TOR  SG       78          2804
# 422 NBA    Isaiah Thomas    BOS  PG       82          2647
# 426 NBA    Klay Thompson    GSW  SG       80          2661
# 98  NBA    Demarcus Cousins SAC  C        65          2245
# 446 NBA    Kemba Walker     CHA  PG       81          2885
# 456 NBA    Andrew Wiggins   MIN  SF       81          2844
# 288 NBA    C.j. Mccollum    POR  SG       80          2776
# 274 NBA    Kyle Lowry       TOR  PG       77          2853
# ...

# %% [markdown]
# 用subset()搜尋火箭隊

# %%
subset(NBA1516,Team=="HOU")
# Out:
#     League Name             Team Position GamesPlayed TotalMinutesPlayed
# 24  NBA    Trevor Ariza     HOU  SF       81          2860
# 44  NBA    Michael Beasley  HOU  PF       20           360
# 47  NBA    Patrick Beverley HOU  PG       71          2038
# 62  NBA    Corey Brewer     HOU  SG       82          1670
# 79  NBA    Clint Capela     HOU  C        77          1468
# 113 NBA    Sam Dekker       HOU  SF        3             7
# 163 NBA    Andre Goudelock  HOU  PG        8            51
# 178 NBA    James Harden     HOU  SG       82          3121
# 181 NBA    Montrez Harrell  HOU  PF       39           378
# 189 NBA    Chuck Hayes      HOU  PF        2            24
# 209 NBA    Dwight Howard    HOU  C        71          2281
# 240 NBA    Terrence Jones   HOU  PF       50          1047
# 291 NBA    K.j. Mcdaniels   HOU  SG       37           238
# 317 NBA    Dona Motiejunas  HOU  PF       37           547
# 405 NBA    Josh Smith       HOU  SF       55           878
# ...

# %% [markdown]
# 用grepl()列出名字有John的人

# %%
NBA1516[grepl("John",NBA1516$Name),]
# Out:
#     League Name            Team Position GamesPlayed TotalMinutesPlayed
# 192 NBA    John Henson     MIL  PF       57           959
# 226 NBA    John Jenkins    PHO  SG       43           474
# 229 NBA    Amir Johnson    BOS  PF       79          1798
# 230 NBA    Chris Johnson   UTA  SF       70           858
# 231 NBA    James Johnson   TOR  PF       57           924
# 232 NBA    Joe Johnson     MIA  SF       81          2703
# 233 NBA    Orlando Johnson NOR  SG        7           102
# 234 NBA    Stanley Johnson DET  SF       73          1685
# 235 NBA    Tyler Johnson   MIA  SG       36           862
# 236 NBA    Wesley Johnson  LAC  SG       80          1664
# 336 NBA    Johnny O'bryant MIL  PF       66           861
# 447 NBA    John Wall       WAS  PG       77          2783
#     FieldGoalsMade FieldGoalsAttempted ThreesMade ThreesAttempted ⋯ Steals
# 192 164             291                  0          1             ⋯  18
# ...

# %% [markdown]
# 散布圖
# x = ThreesAttempted
# y = ThreesMade

# %%
ggplot(NBA1516,aes(x = ThreesAttempted,y = ThreesMade))+geom_point(fill="")
# Out:
# plot without title

# %% [markdown]
# 長條圖
# x = ThreesMade

# %%
ggplot(NBA1516,aes(x = ThreesAttempted),color=Position)+geom_bar()
# Out:
# plot without title

# %% [markdown]
# 折線圖
# x = Turnovers
# y = Steals

# %%
ggplot(NBA1516,aes(x=Turnovers,y=Steals),color = )+geom_line()
# Out:
# plot without title

# %% [markdown]
# 趨勢圖
# x = Turnovers
# y = Steals

# %%
qplot(Turnovers,Steals,data=NBA1516,geom = c("point","smooth"))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
